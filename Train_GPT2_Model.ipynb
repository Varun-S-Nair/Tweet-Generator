# %%
# Defining Custom Variables

number_of_training_steps = 2500
run_Name = "run2500-newer"
model = "335M"
file_Name = "realDonaldTrump.txt"
file_path = "https://github.com/Varun-S-Nair/Trump-Tweet-Generator/raw/master/GPT-2Backend/realDonaldTrump.txt"

# %%
# %tensorflow_version 1.x
# !pip3 install gpt-2-simple
import gpt_2_simple as gpt2
import tensorflow as tf
import os
import requests
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# Collecting gpt-2-simple
#   Downloading https://files.pythonhosted.org/packages/6f/e4/a90add0c3328eed38a46c3ed137f2363b5d6a07bf13ee5d5d4d1e480b8c3/gpt_2_simple-0.7.1.tar.gz
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gpt-2-simple) (1.18.5)
# Collecting toposort
#   Downloading https://files.pythonhosted.org/packages/e9/8a/321cd8ea5f4a22a06e3ba30ef31ec33bea11a3443eeb1d89807640ee6ed4/toposort-1.5-py2.py3-none-any.whl
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->gpt-2-simple) (2020.4.5.1)
# Building wheels for collected packages: gpt-2-simple
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7.1-cp36-none-any.whl size=23581 sha256=b1fbf6247ad1e056a8c90c9c180baae5a0c94867751bcf749c93ded829655b65
#   Stored in directory: /root/.cache/pip/wheels/0c/f8/23/b53ce437504597edff76bf9c3b8de08ad716f74f6c6baaa91a
# Successfully built gpt-2-simple
# Installing collected packages: toposort, gpt-2-simple
# Successfully installed gpt-2-simple-0.7.1 toposort-1.5
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2.mount_gdrive()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Mon Jun 15 23:40:33 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
model_name = model
if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/124M/
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 249Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 74.8Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 527Mit/s]
# Downloading 355M model...
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:13, 104Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 236Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 59.3Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 175Mit/s]

# %%
file_name = tf.keras.utils.get_file(file_Name, file_path)
# Out:
# Downloading data from https://github.com/Varun-S-Nair/Trump-Tweet-Generator/raw/master/GPT-2Backend/realDonaldTrump.txt
# 1114112/1108088 [==============================] - 0s 0us/step

# %% [markdown]
# ## Finetune GPT-2
#
# The next cell will start the actual finetuning of GPT-2. It creates a persistent TensorFlow session which stores the training config, then runs the training for the specified number of `steps`. (to have the finetuning run indefinitely, set `steps = -1`)
#
# The model checkpoints will be saved in `/checkpoint/run1` by default. The checkpoints are saved every 500 steps (can be changed) and when the cell is stopped.
#
# The training might time out after 4ish hours; make sure you end training and save the results so you don't lose them!
#
# **IMPORTANT NOTE:** If you want to rerun this cell, **restart the VM first** (Runtime -> Restart Runtime). You will need to rerun imports but not recopy files.
#
# Other optional-but-helpful parameters for `gpt2.finetune`:
#
#
# *  **`restore_from`**: Set to `fresh` to start training from the base GPT-2, or set to `latest` to restart training from an existing checkpoint.
# * **`sample_every`**: Number of steps to print example output
# * **`print_every`**: Number of steps to print training progress.
# * **`learning_rate`**:  Learning rate for the training. (default `1e-4`, can lower to `1e-5` if you have <1MB input data)
# *  **`run_name`**: subfolder within `checkpoint` to save the model. This is useful if you want to work with multiple models (will also need to specify  `run_name` when loading the model)
# * **`overwrite`**: Set to `True` if you want to continue finetuning an existing model (w/ `restore_from='latest'`) without creating duplicate copies.

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              model_name=model_name,
              restore_from="fresh",
              run_name=run_Name,
              steps=number_of_training_steps)   # steps is max number of training steps
gpt2.copy_checkpoint_to_gdrive(run_name=run_Name, copy_folder=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:01<00:00,  1.88s/it]
# dataset has 255621 tokens
# Training...
# [1 | 13.99] loss=3.35 avg=3.35
# [2 | 16.98] loss=3.48 avg=3.42
# [3 | 19.99] loss=3.31 avg=3.38
# [4 | 23.00] loss=3.26 avg=3.35
# [5 | 26.02] loss=3.42 avg=3.37
# [6 | 29.04] loss=3.35 avg=3.36
# [7 | 32.05] loss=3.35 avg=3.36
# [8 | 35.07] loss=3.32 avg=3.36
# [9 | 38.09] loss=3.29 avg=3.35
# [10 | 41.12] loss=3.11 avg=3.32
# [11 | 44.16] loss=2.79 avg=3.27
# [12 | 47.19] loss=2.98 avg=3.25
# [13 | 50.23] loss=3.44 avg=3.26
# [14 | 53.27] loss=3.22 avg=3.26
# [15 | 56.33] loss=3.17 avg=3.25
# [16 | 59.37] loss=3.22 avg=3.25
# [17 | 62.41] loss=2.95 avg=3.23
# [18 | 65.46] loss=3.15 avg=3.23
# [19 | 68.49] loss=3.11 avg=3.22
# [20 | 71.54] loss=2.99 avg=3.21
# [21 | 74.60] loss=3.07 avg=3.20
# [22 | 77.65] loss=3.21 avg=3.20
# [23 | 80.71] loss=2.83 avg=3.18
# [24 | 83.77] loss=3.07 avg=3.18
# [25 | 86.83] loss=3.26 avg=3.18
# [26 | 89.89] loss=3.50 avg=3.19
# [27 | 92.97] loss=3.19 avg=3.19
# [28 | 96.03] loss=2.44 avg=3.16
# [29 | 99.10] loss=3.22 avg=3.17
# [30 | 102.16] loss=3.24 avg=3.17
# [31 | 105.22] loss=2.98 avg=3.16
# [32 | 108.28] loss=3.25 avg=3.16
# [33 | 111.35] loss=2.27 avg=3.13
# [34 | 114.42] loss=3.11 avg=3.13
# [35 | 117.49] loss=2.98 avg=3.13
# [36 | 120.56] loss=2.68 avg=3.11
# [37 | 123.63] loss=2.90 avg=3.11
# [38 | 126.70] loss=2.89 avg=3.10
# [39 | 129.76] loss=2.90 avg=3.09
# [40 | 132.83] loss=2.77 avg=3.08
# [41 | 135.89] loss=3.43 avg=3.09
# [42 | 138.95] loss=3.14 avg=3.09
# [43 | 142.01] loss=3.29 avg=3.10
# [44 | 145.08] loss=3.19 avg=3.10
# [45 | 148.15] loss=3.08 avg=3.10
# [46 | 151.21] loss=3.05 avg=3.10
# [47 | 154.27] loss=3.22 avg=3.10
# [48 | 157.33] loss=3.20 avg=3.11
# [49 | 160.38] loss=2.94 avg=3.10
# [50 | 163.46] loss=3.06 avg=3.10
# [51 | 166.54] loss=2.76 avg=3.09
# [52 | 169.59] loss=3.14 avg=3.09
# [53 | 172.65] loss=3.12 avg=3.09
# [54 | 175.72] loss=3.23 avg=3.10
# [55 | 178.79] loss=3.30 avg=3.10
# [56 | 181.87] loss=2.86 avg=3.10
# [57 | 184.92] loss=3.04 avg=3.10
# [58 | 187.99] loss=3.16 avg=3.10
# [59 | 191.08] loss=2.99 avg=3.09
# [60 | 194.13] loss=2.91 avg=3.09
# [61 | 197.20] loss=2.98 avg=3.09
# [62 | 200.26] loss=2.92 avg=3.08
# [63 | 203.33] loss=3.16 avg=3.09
# [64 | 206.39] loss=2.92 avg=3.08
# [65 | 209.45] loss=3.00 avg=3.08
# [66 | 212.51] loss=3.00 avg=3.08
# [67 | 215.58] loss=2.56 avg=3.07
# [68 | 218.63] loss=2.96 avg=3.07
# [69 | 221.71] loss=2.43 avg=3.05
# [70 | 224.77] loss=2.79 avg=3.05
# [71 | 227.84] loss=2.78 avg=3.04
# [72 | 230.90] loss=3.12 avg=3.04
# [73 | 233.97] loss=3.11 avg=3.05
# [74 | 237.03] loss=3.19 avg=3.05
# [75 | 240.11] loss=2.66 avg=3.04
# [76 | 243.17] loss=2.56 avg=3.03
# [77 | 246.24] loss=2.73 avg=3.03
# [78 | 249.30] loss=2.49 avg=3.02
# [79 | 252.36] loss=3.09 avg=3.02
# [80 | 255.41] loss=2.84 avg=3.01
# [81 | 258.49] loss=2.43 avg=3.00
# [82 | 261.55] loss=2.55 avg=3.00
# [83 | 264.63] loss=2.84 avg=2.99
# [84 | 267.70] loss=2.98 avg=2.99
# [85 | 270.77] loss=2.33 avg=2.98
# [86 | 273.83] loss=3.08 avg=2.98
# [87 | 276.90] loss=2.64 avg=2.98
# [88 | 279.97] loss=3.22 avg=2.98
# [89 | 283.06] loss=2.33 avg=2.97
# [90 | 286.13] loss=3.23 avg=2.97
# [91 | 289.20] loss=3.03 avg=2.98
# [92 | 292.27] loss=2.65 avg=2.97
# [93 | 295.33] loss=3.08 avg=2.97
# [94 | 298.41] loss=2.89 avg=2.97
# [95 | 301.47] loss=2.49 avg=2.96
# [96 | 304.54] loss=2.93 avg=2.96
# [97 | 307.60] loss=1.93 avg=2.95
# [98 | 310.67] loss=2.18 avg=2.93
# [99 | 313.73] loss=2.59 avg=2.93
# [100 | 316.80] loss=2.56 avg=2.92
# ======== SAMPLE 1 ========
#  Voting for the Democrats was a disaster. Their Nomination went to an extreme, and even the New York Times said so. They are BAD (and get it)!
# I want to thank the people of Texas and Louisiana. If the Democrats can stop the good work being done in those two States, then we can make a deal. We are so busy working on our D.C. Agenda, we can't focus on the other agenda. Get back to work!
# There is no such thing as free trade, they just have other people come and take our jobs. The world owes us a lot!
# It is a travesty and disgrace that the U.S. has such a low tariff rate. We should have a 35% tariff rate, but we don’t. Why should I be allowed to come into the U.S. and buy things that sell for much less than me?
# Can you believe that the Democrats have lost more Legislative Midterms than Republicans. They make a mockery of the very work that was done by the Democrats in the Senate. Why is it that their agenda is not helping, or is doing nothing, the American people?
# I don’t have time for the Dems, they are just looking for fights!
# After 17 years, it is finally time to end the WALL (it costs so much money & takes so long) and build the Wall!
# We are now in the process of having two meetings on the 2nd Border Wall. It will be a beautiful thing!
# The Democrats have no ideas for how to fix our Country’s terrible trade deals. We must get tough and work something out that will fix the terrible trade deals in place!
# China isn’t giving us the information we need. They have taken advantage of us for years!
# With the exception of Senator Ted Cruz, all of those in the Fake News media have betrayed their basic, unwavering commitment to political correctness. I look forward to making up stories and sources to suit our agenda!
# The Democrats are totally unelectable, and their support (even after so many defeats) for President Obama has just become the Democrat Policy. Our country is not so great without our next President and First Lady!
# The Democrats should be thanking Congress for passing the Farm Bill, but not taking credit for its success!
# The Republicans, especially our great Governor, are doing a great job, especially on Energy. But I have an idea!
# I fully support President El Presidente and the fact that the Republican Party won the midterm elections!
# The Democrats, who have made the Republicans look like Nazis and who refuse to support our great Military and our great 2nd Amendment, are not interested in the Presidency, they are interested in destroying it!
# Congratulations to the United States of America on yet another historic victory. With China deciding to get along with the world and put a great deal of value on their currency, they will be putting more pressure on U.S. Treasuries. We will respond!
# After 17 years of the same failed approach, we are back to a different era. There are only 2 things being done in this World, Fighting and Fighting (the World is watching)!
# So true, we are having so much fun, but there is no turning back!
# “The Democrats are now calling for a border tax. We want to build a wall that will be great for our Country!
# The New York Times is trying to be politically correct in their headline about the upcoming election. They don’t want my vote. They don’t want me!
# So true that they don’t want me because I voted for border tax. But they don’t want to say, well, we will make you vote at the polls if you vote against us in 2020. So false!
# The Democrats are now trying to get me to support a border tax. I vote against them because they want more jobs and higher wages. I want us to get along, not to have war, but our country cannot take 6 years and be divided!
# We are having such a great time, and as you watch, our country is blessed with so many talented and accomplished young people. It would be a horrible thing to lose them all, but we must fight for what is right!
# The Failing and dishonest News is trying so hard to be objective. All of the new stories about Trump are made up. Fake stories!
# No new stories, just out that the Democrats are preparing to attack the Trump administration. I have great confidence in President John F. Kennedy. They will not get what they deserve!
# We are now living through a historic economy, and with it, jobs and growth. It means there is nothing that the Democrats can do for the long-term interests of the United States!
# I will be interviewed by @MariaBartiromo tomorrow on Maria. If that is her first interview with her show, I’ll take it!
# The New York
#
# [101 | 359.38] loss=3.12 avg=2.93
# [102 | 362.44] loss=2.97 avg=2.93
# [103 | 365.50] loss=3.11 avg=2.93
# [104 | 368.56] loss=3.06 avg=2.93
# [105 | 371.62] loss=2.81 avg=2.93
# [106 | 374.69] loss=2.15 avg=2.92
# [107 | 377.75] loss=2.89 avg=2.92
# [108 | 380.81] loss=2.88 avg=2.92
# [109 | 383.87] loss=2.91 avg=2.92
# [110 | 386.93] loss=2.90 avg=2.92
# [111 | 389.99] loss=3.05 avg=2.92
# [112 | 393.05] loss=2.46 avg=2.91
# [113 | 396.11] loss=2.53 avg=2.91
# [114 | 399.17] loss=2.86 avg=2.90
# [115 | 402.23] loss=2.51 avg=2.90
# [116 | 405.29] loss=2.23 avg=2.89
# [117 | 408.36] loss=2.90 avg=2.89
# [118 | 411.42] loss=2.77 avg=2.89
# [119 | 414.50] loss=2.42 avg=2.88
# [120 | 417.57] loss=1.98 avg=2.87
# [121 | 420.63] loss=2.52 avg=2.86
# [122 | 423.70] loss=2.96 avg=2.86
# [123 | 426.77] loss=2.94 avg=2.87
# [124 | 429.84] loss=3.19 avg=2.87
# [125 | 432.92] loss=2.36 avg=2.86
# [126 | 435.98] loss=3.16 avg=2.87
# [127 | 439.06] loss=2.40 avg=2.86
# [128 | 442.14] loss=3.20 avg=2.87
# [129 | 445.21] loss=3.10 avg=2.87
# [130 | 448.28] loss=3.23 avg=2.87
# [131 | 451.37] loss=2.91 avg=2.87
# [132 | 454.44] loss=2.34 avg=2.87
# [133 | 457.51] loss=2.84 avg=2.87
# [134 | 460.59] loss=2.53 avg=2.86
# [135 | 463.66] loss=2.38 avg=2.86
# [136 | 466.75] loss=2.67 avg=2.85
# [137 | 469.82] loss=2.73 avg=2.85
# [138 | 472.89] loss=2.76 avg=2.85
# [139 | 475.97] loss=2.49 avg=2.85
# [140 | 479.05] loss=2.32 avg=2.84
# [141 | 482.13] loss=2.79 avg=2.84
# [142 | 485.21] loss=2.51 avg=2.83
# [143 | 488.28] loss=2.97 avg=2.84
# [144 | 491.36] loss=2.12 avg=2.83
# [145 | 494.43] loss=2.13 avg=2.82
# [146 | 497.51] loss=3.31 avg=2.82
# [147 | 500.58] loss=2.57 avg=2.82
# [148 | 503.66] loss=2.55 avg=2.82
# [149 | 506.74] loss=3.01 avg=2.82
# [150 | 509.82] loss=3.03 avg=2.82
# [151 | 512.89] loss=2.55 avg=2.82
# [152 | 515.97] loss=2.54 avg=2.81
# [153 | 519.05] loss=2.54 avg=2.81
# [154 | 522.11] loss=2.53 avg=2.81
# [155 | 525.18] loss=3.21 avg=2.81
# [156 | 528.26] loss=2.97 avg=2.81
# [157 | 531.34] loss=2.32 avg=2.81
# [158 | 534.42] loss=2.45 avg=2.80
# [159 | 537.50] loss=2.75 avg=2.80
# [160 | 540.57] loss=2.94 avg=2.80
# [161 | 543.64] loss=2.71 avg=2.80
# [162 | 546.73] loss=3.02 avg=2.81
# [163 | 549.79] loss=2.89 avg=2.81
# [164 | 552.86] loss=2.24 avg=2.80
# [165 | 555.94] loss=2.92 avg=2.80
# [166 | 559.01] loss=3.19 avg=2.81
# [167 | 562.07] loss=2.08 avg=2.80
# [168 | 565.15] loss=2.90 avg=2.80
# [169 | 568.22] loss=2.49 avg=2.80
# [170 | 571.30] loss=2.82 avg=2.80
# [171 | 574.38] loss=1.97 avg=2.79
# [172 | 577.46] loss=2.01 avg=2.78
# [173 | 580.54] loss=2.21 avg=2.77
# [174 | 583.61] loss=3.15 avg=2.77
# [175 | 586.69] loss=2.31 avg=2.77
# [176 | 589.76] loss=2.75 avg=2.77
# [177 | 592.83] loss=3.06 avg=2.77
# [178 | 595.90] loss=2.34 avg=2.77
# [179 | 598.98] loss=2.54 avg=2.76
# [180 | 602.05] loss=2.06 avg=2.76
# [181 | 605.13] loss=3.12 avg=2.76
# [182 | 608.20] loss=2.66 avg=2.76
# [183 | 611.28] loss=2.11 avg=2.75
# [184 | 614.36] loss=2.92 avg=2.75
# [185 | 617.43] loss=2.48 avg=2.75
# [186 | 620.50] loss=2.23 avg=2.74
# [187 | 623.57] loss=2.39 avg=2.74
# [188 | 626.64] loss=3.14 avg=2.74
# [189 | 629.75] loss=2.92 avg=2.75
# [190 | 632.82] loss=2.28 avg=2.74
# [191 | 635.90] loss=3.30 avg=2.75
# [192 | 638.98] loss=2.84 avg=2.75
# [193 | 642.06] loss=2.28 avg=2.74
# [194 | 645.13] loss=2.81 avg=2.74
# [195 | 648.21] loss=2.73 avg=2.74
# [196 | 651.27] loss=2.64 avg=2.74
# [197 | 654.35] loss=2.58 avg=2.74
# [198 | 657.42] loss=3.03 avg=2.74
# [199 | 660.49] loss=2.87 avg=2.75
# [200 | 663.57] loss=2.07 avg=2.74
# ======== SAMPLE 1 ========
#  has all of these documents from Russia, and the phony Russia collusion charges. Where is the Collusion case? They are all Crooked Hillary crimes.
# After being caught red handed, President Trump has no choice but to get even with the Dems. We are looking at an election. What has they done to show obstruction and illegality?
# The Democrats in control of the Supreme Court are putting the lives of our Nation's heroes, our heroes in all different branches of Military, Police & First Responders in danger. This should be a top priority of all Governors!
# “Hillary Clinton’s private e-mails were used by the Democrats to win the election and it wasn’t even fair. The investigation has gone totally wrong and the Investigation Committee is a total scam. The President should have no choice but to be angry about this whole thing.” James Freeman, Law & Order.
# “What the @S&P500 did today was a big day for the FBI which has been a big disappointment but nothing to look forward to. The Mueller Report was the most important of the Mueller 2.0 Report. It’s been in the making for a long time, and now it’s finally there. It’s been leaked and discredited, yet we get a small piece of it.” James Freeman, of the S&P. 100.
# The Mueller Report shows that the FBI, which was unable to prove Obstruction from the beginning, was a crooked operation from the beginning. The House Intelligence Committee report says the Mueller Report is very good for the FBI, and it should be released to the public. Why haven’t I seen this? A Fake News Media!
# The Mueller Report shows that the FBI, which was unable to prove Obstruction from the beginning, was a crooked operation from the beginning. The House Intelligence Committee Report says that the Mueller Report is very good for the FBI, and it should be released to the public. Why haven’t I seen this? A Fake News Media!
# The Mueller Report shows that there was no Obstruction from the beginning by the FBI. The Democrats in Congress are working VERY hard to change the Mueller Report, but the fact is, it is a Fake. They will never be able to get through what the Mueller Report, and so many things, says, about Russia. Never heard of collusion, or obstruction charges!
# With all of the Fake News we are fed, which is almost all, to our great disappointment, no matter for what reason, it is still good news, and all of this bad reporting continues. Sad to see how Media is doing so badly. We are being lied to. Sad!
# When will the House Intelligence Committee report on the so-called ‘Mueller Report’ turn up the heat on the Democrats, especially the Democrats in Congress, for their very bad and illegal conduct? Sad!
# If we are forced to go to war based on the findings of what the Mueller Report says about Russia etc., it will not be the first time we have fought back. We have fought back so many times against NATO, in the form of defense spending, taxes, & military spending. These things, for which we have been fighting back from the beginning, will never be allowed!
# No matter what happens with respect to NATO, or any other military alliance, America will win!
# Thank you to Dennis Mitchell (@CNNPolitics) for showing me some of the great statistics from NATO where we have made tremendous contributions, saved countless lives, put our troops in harm’s way and won!
# NATO is getting even better and stronger with Russia, many times. Will NATO & Russia be able to meet again this way!
# Thank you Mark Levin of @TheMarkLevinShow for your kind words on @FoxNews!
# Very happy to announce that the Mueller Report gave me an even bigger and bigger victory. The Media has been trying desperately to change the findings of what the Mueller Report finally says for three years, only to realize that the results of the Report are, in fact, far better than their “interpretations.” Also, the @CNN is not fair, they don’t want to be honest!
# It was totally political by @RepDanKavanaugh, who could be the biggest Republican ever, yet he was unable to make one critical point. Remember, he is only 70 years old!
# I am delighted to announce that my Administration will be moving forward on the North Atlantic Treaty Organization. This is a big step in the right direction, and we have been working toward this and achieving success for a while, thanks!
# The Mueller Report shows there was no Obstruction. The Democrats are looking at the facts and following the facts. This should all be given full attention. The Republicans also should be taking this up at the State of the Union.
# There has never been anyone so dishonest. It is all designed to hurt the President and his Administration, and those close to him!
#
# [201 | 703.21] loss=1.82 avg=2.73
# [202 | 706.27] loss=2.40 avg=2.72
# [203 | 709.31] loss=2.93 avg=2.73
# [204 | 712.37] loss=2.42 avg=2.72
# [205 | 715.42] loss=3.03 avg=2.73
# [206 | 718.49] loss=2.65 avg=2.72
# [207 | 721.56] loss=1.53 avg=2.71
# [208 | 724.62] loss=2.58 avg=2.71
# [209 | 727.69] loss=2.09 avg=2.70
# [210 | 730.75] loss=2.42 avg=2.70
# [211 | 733.82] loss=1.84 avg=2.69
# [212 | 736.89] loss=2.82 avg=2.69
# [213 | 739.96] loss=2.31 avg=2.69
# [214 | 743.04] loss=1.67 avg=2.67
# [215 | 746.10] loss=1.81 avg=2.67
# [216 | 749.17] loss=1.94 avg=2.66
# [217 | 752.24] loss=3.19 avg=2.66
# [218 | 755.31] loss=2.73 avg=2.66
# [219 | 758.39] loss=2.03 avg=2.66
# [220 | 761.46] loss=2.72 avg=2.66
# [221 | 764.54] loss=2.44 avg=2.65
# [222 | 767.61] loss=2.48 avg=2.65
# [223 | 770.69] loss=2.22 avg=2.65
# [224 | 773.77] loss=2.22 avg=2.64
# [225 | 776.85] loss=2.44 avg=2.64
# [226 | 779.93] loss=1.72 avg=2.63
# [227 | 783.00] loss=2.89 avg=2.63
# [228 | 786.07] loss=2.60 avg=2.63
# [229 | 789.16] loss=2.90 avg=2.64
# [230 | 792.23] loss=3.20 avg=2.64
# [231 | 795.30] loss=2.98 avg=2.65
# [232 | 798.36] loss=2.41 avg=2.64
# [233 | 801.43] loss=2.61 avg=2.64
# [234 | 804.52] loss=2.79 avg=2.64
# [235 | 807.59] loss=2.80 avg=2.65
# [236 | 810.67] loss=1.82 avg=2.64
# [237 | 813.75] loss=2.83 avg=2.64
# [238 | 816.83] loss=2.93 avg=2.64
# [239 | 819.90] loss=2.80 avg=2.64
# [240 | 822.98] loss=2.78 avg=2.65
# [241 | 826.06] loss=2.31 avg=2.64
# [242 | 829.14] loss=2.44 avg=2.64
# [243 | 832.20] loss=2.73 avg=2.64
# [244 | 835.28] loss=2.49 avg=2.64
# [245 | 838.34] loss=2.46 avg=2.64
# [246 | 841.42] loss=2.08 avg=2.63
# [247 | 844.49] loss=2.22 avg=2.63
# [248 | 847.56] loss=2.21 avg=2.62
# [249 | 850.64] loss=3.12 avg=2.63
# [250 | 853.72] loss=2.24 avg=2.62
# [251 | 856.80] loss=2.73 avg=2.62
# [252 | 859.87] loss=2.12 avg=2.62
# [253 | 862.94] loss=2.75 avg=2.62
# [254 | 865.99] loss=1.74 avg=2.61
# [255 | 869.06] loss=2.38 avg=2.61
# [256 | 872.15] loss=2.51 avg=2.61
# [257 | 875.22] loss=1.89 avg=2.60
# [258 | 878.30] loss=2.56 avg=2.60
# [259 | 881.39] loss=2.00 avg=2.59
# [260 | 884.46] loss=1.00 avg=2.58
# [261 | 887.54] loss=2.44 avg=2.57
# [262 | 890.61] loss=3.27 avg=2.58
# [263 | 893.70] loss=2.29 avg=2.58
# [264 | 896.77] loss=1.88 avg=2.57
# [265 | 899.84] loss=2.18 avg=2.57
# [266 | 902.92] loss=2.33 avg=2.56
# [267 | 906.00] loss=2.30 avg=2.56
# [268 | 909.07] loss=1.77 avg=2.55
# [269 | 912.14] loss=1.52 avg=2.54
# [270 | 915.22] loss=2.71 avg=2.54
# [271 | 918.29] loss=2.70 avg=2.55
# [272 | 921.37] loss=1.71 avg=2.54
# [273 | 924.44] loss=2.27 avg=2.53
# [274 | 927.51] loss=2.32 avg=2.53
# [275 | 930.57] loss=1.97 avg=2.53
# [276 | 933.64] loss=2.62 avg=2.53
# [277 | 936.72] loss=2.42 avg=2.53
# [278 | 939.79] loss=3.14 avg=2.53
# [279 | 942.86] loss=2.15 avg=2.53
# [280 | 945.94] loss=2.09 avg=2.52
# [281 | 949.01] loss=2.52 avg=2.52
# [282 | 952.09] loss=2.95 avg=2.53
# [283 | 955.16] loss=2.13 avg=2.52
# [284 | 958.23] loss=2.35 avg=2.52
# [285 | 961.31] loss=1.78 avg=2.51
# [286 | 964.39] loss=1.25 avg=2.50
# [287 | 967.46] loss=2.37 avg=2.50
# [288 | 970.53] loss=3.04 avg=2.50
# [289 | 973.61] loss=2.65 avg=2.51
# [290 | 976.69] loss=3.28 avg=2.51
# [291 | 979.77] loss=1.51 avg=2.50
# [292 | 982.83] loss=2.46 avg=2.50
# [293 | 985.91] loss=2.35 avg=2.50
# [294 | 988.99] loss=1.31 avg=2.49
# [295 | 992.07] loss=2.60 avg=2.49
# [296 | 995.15] loss=2.92 avg=2.49
# [297 | 998.24] loss=2.13 avg=2.49
# [298 | 1001.31] loss=2.85 avg=2.49
# [299 | 1004.38] loss=1.79 avg=2.49
# [300 | 1007.44] loss=1.12 avg=2.47
# ======== SAMPLE 1 ========
#  primary leadership of our Free World, the worst we've ever seen is the Radical Left Candidate, Crooked Hillary, that was eventually defeated in the primaries. That was the best we ever got! The Radical Left is weak and does not know how to win, and they are failing!
# A BIG and LOUD JOB for the President to be able to Make the decision to HOLD or RESIGN, and then to LOSE the Election in 2020!
# The Fake News Media has gone totally mad! They report and write whatever they want, like never before. Fake, Fake news!
# “The President will make a very strong and good decision.” @seanhannity
# “This guy’s been through hell and back but he still thinks he can run for President.” @FoxNews @MZGriffin @seanhannity
# “Pundits have been calling this President’s Crisis of Consciousness, the Emergency, and it’s just not on. This is not a crisis in his mind. This is an emergency in his heart.” @Varneyco @seanhannity @FoxNews And so the Radical Left is running around the country trying to blame this President for whatever happened in the 2016 Campaign. This should never be allowed!
# The Radical Left Democrats are getting worse and worse and worse. They are only interested in making our Country worse over and over again. They are also getting less and less liberal. They are nothing but the Sadists!
# “Our economy is doing great.” @LindseyGrahamSC @SenCato @MikeLeehenry
# When a country is a disaster, like it is right now, it does not matter what party is in power, the Media will continue to report that. If a country is doing as well as it is doing, then “we’re all Americans”!
# It’s now become apparent that Hillary Clinton’s top aide, yuri gmail, was set up, in a coordinated fashion, to destroy, and in the process, get thousands and thousands of illegally deleted Emails. So stupid! So what? This should never have happened!
# It was a big and historic day in U.S. foreign policy today. The U.S. took away Russia “s top diplomat,” and in so doing, did massive diplomatic damage. The Radical Left Congress, led by Nancy Pelosi and Chuck Schumer, made a mockery of the historic Tweaks!
# The Radical Party has done nothing to deserve the Impeachment penalty it has been subjected to. It is a party whose core beliefs are that all Americans should be punished, that it is only a Democrat “purge” of the Radical Left. So bad for a great and beautiful Party!
# The Democrats have gone Crazy! But what about the Radical Left, Crooked Hillary and the many other losers that she left behind? How come we got nothing accomplished, only more lost time and energy?
# Great new book out on the Radical Left Democrats, “The Leftover Radicals,” by Charles J. Watson, “the former head of the FBI.” It is so important to the future of our Country!
# “This is a perfect storm – the House Republicans want to be rid of the many unpopular members and come back to D.C., but the Dems want to stay in the future," President @BretBaier of Fox News.
# As the Democrats continue to get worse and worse, the Republican Party as a whole is doing very well, perhaps even better than ever before. The Radical Left members of Congress never left. The Radical Democrats have been badly treated. No votes for Radical Democrats!
# “Republicans have been able to get two pieces of legislation through Congress.” @seanhannity Good for the Country!
# “There’s no question that the Radical Democrats are the Party of No “No”.” @CNN Poll: 43% of Republicans think this way, a Record. If the Democrats had won, would be worse!
# We are bringing jobs back to the states that they have been lost to the Democrats by executive action. Our courts were designed without a Supreme Court, the worst decisions ever made, and are being replaced with the worst imaginable, with even more Radical Proposal!
# If the Democrats are unable to give us HCare, or to give us great Healthcare, they must come together and work w/ us, no deal!
# The Radical Left Democrats are not impressed by the Merit Based, “caregiving” system of government we have in our Country. They want Social Security and Medicare for All. They want “safety net” on top of Safety Net!
# “A very big and very fair victory for the Republican Party.” @foxandfriends
# The House Republicans want to be rid of the many unpopular
#
# [301 | 1047.59] loss=1.80 avg=2.47
# [302 | 1050.65] loss=2.81 avg=2.47
# [303 | 1053.71] loss=2.67 avg=2.47
# [304 | 1056.77] loss=2.02 avg=2.47
# [305 | 1059.84] loss=2.63 avg=2.47
# [306 | 1062.90] loss=2.49 avg=2.47
# [307 | 1065.96] loss=1.95 avg=2.46
# [308 | 1069.03] loss=2.06 avg=2.46
# [309 | 1072.09] loss=1.95 avg=2.45
# [310 | 1075.15] loss=2.27 avg=2.45
# [311 | 1078.21] loss=1.94 avg=2.45
# [312 | 1081.26] loss=1.85 avg=2.44
# [313 | 1084.33] loss=2.26 avg=2.44
# [314 | 1087.40] loss=2.31 avg=2.44
# [315 | 1090.46] loss=1.77 avg=2.43
# [316 | 1093.54] loss=2.14 avg=2.43
# [317 | 1096.61] loss=2.27 avg=2.43
# [318 | 1099.68] loss=1.54 avg=2.42
# [319 | 1102.74] loss=3.06 avg=2.42
# [320 | 1105.81] loss=2.46 avg=2.42
# [321 | 1108.88] loss=1.82 avg=2.42
# [322 | 1111.97] loss=2.27 avg=2.42
# [323 | 1115.05] loss=2.35 avg=2.41
# [324 | 1118.13] loss=2.25 avg=2.41
# [325 | 1121.20] loss=1.44 avg=2.40
# [326 | 1124.27] loss=3.28 avg=2.41
# [327 | 1127.35] loss=2.45 avg=2.41
# [328 | 1130.43] loss=2.30 avg=2.41
# [329 | 1133.50] loss=2.26 avg=2.41
# [330 | 1136.59] loss=1.42 avg=2.40
# [331 | 1139.66] loss=3.01 avg=2.41
# [332 | 1142.74] loss=1.74 avg=2.40
# [333 | 1145.82] loss=1.81 avg=2.39
# [334 | 1148.89] loss=2.73 avg=2.40
# [335 | 1151.97] loss=3.38 avg=2.41
# [336 | 1155.06] loss=1.80 avg=2.40
# [337 | 1158.13] loss=2.01 avg=2.40
# [338 | 1161.20] loss=2.00 avg=2.39
# [339 | 1164.29] loss=2.29 avg=2.39
# [340 | 1167.37] loss=2.27 avg=2.39
# [341 | 1170.44] loss=1.32 avg=2.38
# [342 | 1173.52] loss=2.04 avg=2.37
# [343 | 1176.59] loss=2.09 avg=2.37
# [344 | 1179.67] loss=1.78 avg=2.37
# [345 | 1182.75] loss=2.90 avg=2.37
# [346 | 1185.83] loss=3.04 avg=2.38
# [347 | 1188.91] loss=1.09 avg=2.37
# [348 | 1191.99] loss=3.06 avg=2.37
# [349 | 1195.06] loss=2.07 avg=2.37
# [350 | 1198.13] loss=1.67 avg=2.36
# [351 | 1201.20] loss=2.44 avg=2.36
# [352 | 1204.27] loss=1.82 avg=2.36
# [353 | 1207.35] loss=2.98 avg=2.36
# [354 | 1210.43] loss=2.91 avg=2.37
# [355 | 1213.50] loss=2.77 avg=2.37
# [356 | 1216.58] loss=1.91 avg=2.37
# [357 | 1219.65] loss=1.87 avg=2.36
# [358 | 1222.72] loss=1.85 avg=2.36
# [359 | 1225.80] loss=2.34 avg=2.36
# [360 | 1228.88] loss=1.76 avg=2.35
# [361 | 1231.95] loss=1.65 avg=2.34
# [362 | 1235.02] loss=1.82 avg=2.34
# [363 | 1238.10] loss=3.08 avg=2.35
# [364 | 1241.17] loss=1.44 avg=2.34
# [365 | 1244.25] loss=2.28 avg=2.34
# [366 | 1247.31] loss=2.90 avg=2.34
# [367 | 1250.37] loss=3.28 avg=2.35
# [368 | 1253.45] loss=2.79 avg=2.36
# [369 | 1256.54] loss=2.01 avg=2.35
# [370 | 1259.61] loss=1.27 avg=2.34
# [371 | 1262.68] loss=1.97 avg=2.34
# [372 | 1265.76] loss=2.12 avg=2.34
# [373 | 1268.83] loss=1.28 avg=2.33
# [374 | 1271.89] loss=1.98 avg=2.32
# [375 | 1274.98] loss=1.55 avg=2.31
# [376 | 1278.05] loss=2.10 avg=2.31
# [377 | 1281.11] loss=3.20 avg=2.32
# [378 | 1284.19] loss=0.92 avg=2.31
# [379 | 1287.28] loss=1.85 avg=2.30
# [380 | 1290.36] loss=1.70 avg=2.30
# [381 | 1293.44] loss=2.59 avg=2.30
# [382 | 1296.53] loss=1.50 avg=2.29
# [383 | 1299.61] loss=2.14 avg=2.29
# [384 | 1302.68] loss=1.93 avg=2.29
# [385 | 1305.75] loss=2.99 avg=2.29
# [386 | 1308.82] loss=2.42 avg=2.29
# [387 | 1311.90] loss=2.54 avg=2.30
# [388 | 1314.97] loss=1.70 avg=2.29
# [389 | 1318.04] loss=3.08 avg=2.30
# [390 | 1321.12] loss=2.12 avg=2.30
# [391 | 1324.19] loss=1.90 avg=2.29
# [392 | 1327.26] loss=1.79 avg=2.29
# [393 | 1330.33] loss=1.16 avg=2.28
# [394 | 1333.41] loss=2.50 avg=2.28
# [395 | 1336.48] loss=2.81 avg=2.28
# [396 | 1339.56] loss=1.41 avg=2.27
# [397 | 1342.63] loss=2.19 avg=2.27
# [398 | 1345.70] loss=1.54 avg=2.27
# [399 | 1348.78] loss=2.91 avg=2.27
# [400 | 1351.85] loss=1.99 avg=2.27
# ======== SAMPLE 1 ========
#  there I will appoint a Special Counsel to look into your for going on 35 years (with a maximum of 5 years), but this would never work.” Thank you, @OANN
# A real WITCH! I would appoint a Special Counsel to look into your long list of lies and crimes against the people and country that we now understand to be so heinous, so big & so expensive. The Witch Hunt is now officially underway.
# Big rush of new jobs created during the July 4th holiday weekend. It was a big one, the biggest in history. Great!
# Just returned to Washington after two long and very successful trips! The United States is looking very much forward to getting there!
# “President Trump has already accomplished more in his first two years than all Governors, Senators, and Legislative Deans combined.” Chris Wallace, Fox News.
# “I’ve been hearing this for years. People have to put up very reasonable taxes.” Bill Hagerty, “Fixing HealthCare” at <http://www.foxnews.com/story/2017/09/05/healthcare-reform-fails-sunday.html>.
# We can take care of all of our great & talented military service members, but our brave and highly valued law enforcement personnel must be allowed to work and protect our country. Our country needs more of them, but especially our HIDDEN VICTIMS (i.e., Law Enforcement).
# The Democrats, which are largely responsible for the Obamacare Mess, have become the Party of High Taxes and High Crime. This is bad news for the middle class and against the very evil things that the Democrats want to do to us. Will they support a Republican for President, much less in 2020?
# When I first announced my candidacy for President, in February 2015, the press was not talking about me at all. Now that I have run a strong race, and have an excellent chance, I am being labeled as high taxes, crime & immigration. In 20 years we will win all three. I’m not very “political,” but everyone is, so I don’t think we need to talk about me!
# I will be endorsing Scott Wadden, a great candidate for Governor of Missouri, in a pretty tough race - VOTE TUESDAY!
# Great job being done by the New York Times team at the White House. The haters want me out (just like they want Crooked Hillary). I can’t blame them!
# “This is really the beginning of the end for the Mueller Report,” said Bob Mueller, President Obama’s Director of the FBI. The only thing not working - nobody knows what. No Collusion, but that’s a non issue!
# Great job being done by the @nytimes and @washingtonpost on the Iran deal. Look forward to being with President @VladimirPoc of Russia later today - GREAT!
# Wow, the Wall Street Journal Editorial Board just stated that, “The President has already done an extraordinary job. He has taken out ISIS, stopped the bleeding from Hurricane Harvey, and many other important tasks!” A better way to put it is, “Praise for President Donald J. Trump is to honor his accomplishments! The Journal always takes a different view.
# Great job being done by @OANN, @CBSNews, @CNN and @Newsmax on your great new national series, @TuckerCarlson. We are with you!
# The new report out of the Department of Justice (that’s a total misstatement) that the Trump campaign was working as an intelligence unit of the Russian government is the worst of the many over the Obama/Biden regime. I just can’t believe that these very smart and knowledgeable people would put themselves in that position without knowing better!
# Congratulations to @GovMikeHuckabee on his big Democratic primary win. He will go down as easily the most successful Governor in the USA! Keep working for hard working Americans, Mike!
# Great job being done by Mitch Moran on @foxandfriends. Great guy is strong on military. @foxandfriends is being easily replaced by @foxandfriends , a total waste of airtime. Mitch, don’t let the Failing New Yorker,  Matt Schlapp, take your place!
# Wow, the New York Times just came out at roughly the same time as the Washington Post, claiming that the Justice Department has the “probe in” (unfounded) collusion probe and, in its most extreme form of it, a criminal investigation that looks far tougher than previously thought. Another Fake News Story!
# We’ve signed a new Trade Agreement with Mexico and Canada for them to follow. That’s really what it all started with!
# Big day out for NAFTA! Mexico just approved the largest tax cut in its history. Big
#
# [401 | 1391.47] loss=2.75 avg=2.27
# [402 | 1394.52] loss=2.18 avg=2.27
# [403 | 1397.58] loss=2.83 avg=2.28
# [404 | 1400.64] loss=2.67 avg=2.28
# [405 | 1403.70] loss=1.61 avg=2.28
# [406 | 1406.78] loss=3.21 avg=2.29
# [407 | 1409.85] loss=1.80 avg=2.28
# [408 | 1412.91] loss=1.94 avg=2.28
# [409 | 1415.97] loss=1.61 avg=2.27
# [410 | 1419.05] loss=2.27 avg=2.27
# [411 | 1422.13] loss=2.27 avg=2.27
# [412 | 1425.18] loss=2.23 avg=2.27
# [413 | 1428.26] loss=1.02 avg=2.26
# [414 | 1431.33] loss=1.90 avg=2.25
# [415 | 1434.39] loss=3.27 avg=2.26
# [416 | 1437.47] loss=2.26 avg=2.26
# [417 | 1440.54] loss=1.20 avg=2.25
# [418 | 1443.61] loss=2.29 avg=2.25
# [419 | 1446.68] loss=2.17 avg=2.25
# [420 | 1449.75] loss=2.61 avg=2.26
# [421 | 1452.83] loss=1.55 avg=2.25
# [422 | 1455.90] loss=2.57 avg=2.25
# [423 | 1458.97] loss=2.19 avg=2.25
# [424 | 1462.05] loss=1.99 avg=2.25
# [425 | 1465.12] loss=1.10 avg=2.24
# [426 | 1468.19] loss=1.85 avg=2.23
# [427 | 1471.27] loss=1.90 avg=2.23
# [428 | 1474.35] loss=1.75 avg=2.23
# [429 | 1477.43] loss=2.24 avg=2.23
# [430 | 1480.51] loss=1.59 avg=2.22
# [431 | 1483.60] loss=2.48 avg=2.22
# [432 | 1486.67] loss=2.93 avg=2.23
# [433 | 1489.75] loss=1.61 avg=2.22
# [434 | 1492.82] loss=2.33 avg=2.22
# [435 | 1495.91] loss=2.89 avg=2.23
# [436 | 1498.98] loss=1.71 avg=2.23
# [437 | 1502.06] loss=2.46 avg=2.23
# [438 | 1505.14] loss=1.38 avg=2.22
# [439 | 1508.21] loss=1.51 avg=2.21
# [440 | 1511.29] loss=1.19 avg=2.20
# [441 | 1514.37] loss=1.84 avg=2.20
# [442 | 1517.45] loss=2.24 avg=2.20
# [443 | 1520.52] loss=1.81 avg=2.19
# [444 | 1523.60] loss=1.43 avg=2.19
# [445 | 1526.69] loss=1.34 avg=2.18
# [446 | 1529.77] loss=1.92 avg=2.18
# [447 | 1532.85] loss=1.87 avg=2.17
# [448 | 1535.93] loss=1.51 avg=2.17
# [449 | 1539.01] loss=2.22 avg=2.17
# [450 | 1542.08] loss=0.86 avg=2.15
# [451 | 1545.16] loss=1.35 avg=2.15
# [452 | 1548.24] loss=1.87 avg=2.14
# [453 | 1551.33] loss=2.38 avg=2.14
# [454 | 1554.39] loss=2.04 avg=2.14
# [455 | 1557.46] loss=2.73 avg=2.15
# [456 | 1560.53] loss=1.29 avg=2.14
# [457 | 1563.59] loss=1.47 avg=2.13
# [458 | 1566.66] loss=1.00 avg=2.12
# [459 | 1569.73] loss=2.27 avg=2.12
# [460 | 1572.80] loss=2.20 avg=2.13
# [461 | 1575.87] loss=0.91 avg=2.11
# [462 | 1578.95] loss=1.92 avg=2.11
# [463 | 1582.03] loss=1.92 avg=2.11
# [464 | 1585.09] loss=1.75 avg=2.11
# [465 | 1588.15] loss=1.12 avg=2.10
# [466 | 1591.22] loss=1.11 avg=2.09
# [467 | 1594.29] loss=1.52 avg=2.08
# [468 | 1597.36] loss=2.20 avg=2.08
# [469 | 1600.43] loss=1.78 avg=2.08
# [470 | 1603.49] loss=1.97 avg=2.08
# [471 | 1606.56] loss=2.69 avg=2.08
# [472 | 1609.64] loss=2.46 avg=2.09
# [473 | 1612.71] loss=1.67 avg=2.08
# [474 | 1615.78] loss=1.65 avg=2.08
# [475 | 1618.85] loss=1.58 avg=2.07
# [476 | 1621.92] loss=1.16 avg=2.06
# [477 | 1624.99] loss=1.84 avg=2.06
# [478 | 1628.06] loss=1.19 avg=2.05
# [479 | 1631.12] loss=2.09 avg=2.05
# [480 | 1634.19] loss=2.11 avg=2.05
# [481 | 1637.26] loss=1.57 avg=2.05
# [482 | 1640.33] loss=2.60 avg=2.05
# [483 | 1643.41] loss=1.49 avg=2.05
# [484 | 1646.48] loss=2.33 avg=2.05
# [485 | 1649.55] loss=1.31 avg=2.04
# [486 | 1652.61] loss=1.42 avg=2.04
# [487 | 1655.69] loss=1.44 avg=2.03
# [488 | 1658.76] loss=2.41 avg=2.04
# [489 | 1661.83] loss=3.05 avg=2.05
# [490 | 1664.91] loss=1.16 avg=2.04
# [491 | 1667.99] loss=2.35 avg=2.04
# [492 | 1671.05] loss=1.35 avg=2.03
# [493 | 1674.13] loss=1.70 avg=2.03
# [494 | 1677.20] loss=1.96 avg=2.03
# [495 | 1680.28] loss=1.83 avg=2.03
# [496 | 1683.35] loss=1.47 avg=2.02
# [497 | 1686.41] loss=2.73 avg=2.03
# [498 | 1689.49] loss=2.45 avg=2.03
# [499 | 1692.57] loss=2.74 avg=2.04
# [500 | 1695.64] loss=3.10 avg=2.05
# ======== SAMPLE 1 ========
# otton, is running for Congress in the Great State of Tennessee. He will get our Country the help it needs, and fast, at a time when our great Military needs it most. Keep our Country and our Military Strong!
# Democrats must now support our GREAT Military. I am bringing back the great Senate Veterans for Trump’s Wall! Great Job! Thank you!
# “He (Obama) has spent millions of dollars and spent nothing on the WALL.” @IngrahamAngle
# It was a really great weekend in Houston for our great Military. A total waste of money. Our great Military has been badly put off by the Fake News for many years. I look forward to seeing all of our Military personnel next week at the Wall that we will build at Texas Military Bases in California and New Mexico.
# Thank you to our Military and their Leaders for a great weekend of dedication and preparation at our Texas Military Bases. It was really fun to watch and observe. We are building the biggest Wall in the World, and it is built to last!
# So interesting to watch how badly the Fake News is writing these days, & particularly the so-called “mainstream” @washingtonpost & @foxandfriends. It is just a continuation of the most dishonest and corrupt effort to win an election in U.S. history. They never even looked at the Wall or Border Security. Sad!
# I never wanted President Obama to be elected. But when he got unopposed, he ran a terrible race, no chance of getting elected! He couldn’t even get a 20% on Election Night (for a really bad result), all he wanted to do is get himself fired from office. But he got that because he was a terrible President!
# With the Republicans becoming the Party of Border Security & Security, it will never be possible to have an acceptable DACA deal!
# A BIG WIN for us in the United States Senate today. After two long years of talking and praying, the great people of Texas won big, and now, for the first time in years, I sign an Immigration Bill. Congratulations Texas, a truly great State. You will soon wonder why you have been complaining all these years! A bill that will make a BIG difference for US
# “Donald Trump is the personification of Trumpism.” @CNBC
# So I went to the White House to see the results of my States of Emergency Speech, which I sent out to the states to give them three days of total preparedness. They had no idea what to expect, all of an emergency. They “should” have had nothing, and were unprepared!
# The President is making history, and the Republican Party, by doing this. It is an unprecedented and wonderful event. Thank you to everyone who has watched and signed the States of Emergency Act, which now has almost 4 million supporters. We will get this done!
# The Great State of Minnesota is proud to again become the National Capital for the First Time EVER. Congratulations to Governor Mike Bach, who will make a FANTASTIC Capital to live and work in!
# I have just signed the States of Emergency Act into law. Thank you @SteveScalise @senatemajldr Mitch McConnell for your wise and compassionate decision-the best/greatest ever! See you tomorrow at 9:00 A.M.
# I will be leaving for Wisconsin, at some time soon, and will be bringing many friends!
# As we celebrate the great people of Wisconsin for the great State House that they helped to build (a major State House with new renovation, better condition than ever), let’s all send condolences to the people of Wisconsin. Your great State will soon be a Capital of the USA again!
# So good to see people are stepping forward to serve time in Texas correctional facilities for stealing a pen from a penitentiary. Very hard to do when you are a hardened felon & thief!!
# Great weekend in Utah. We are all proud of what our Country has accomplished. Now we need YOUR help, please sign and share @TheJusticeCenterPAG. A big and important help for our great Rep. Cory Gardner!
# The Department of Justice is investigating a former U.S. Attorneys Office in Minnesota for possible violations of the Espionage laws. We are working closely with the Minnesota Attorney General to take appropriate action if we find any evidence of a crime. Justice Department
# The Republican Party will win Minnesota, Colorado, North Dakota and Washington. It’s all happening on Tuesday!
# North Dakota is being asked to pay for a border wall by California, which is being asked to pay for a border wall by Georgia which is being asked to pay for border wall by Arizona which is being asked to pay for border wall by Florida which is being asked to pay for border wall by Tennessee which is being asked to pay for border wall by Nevada which is being asked (by Colorado) to pay for border wall - they got money from other states
#
# [501 | 1735.27] loss=1.47 avg=2.05
# [502 | 1738.33] loss=3.34 avg=2.06
# [503 | 1741.39] loss=2.65 avg=2.06
# [504 | 1744.44] loss=2.19 avg=2.07
# [505 | 1747.50] loss=1.27 avg=2.06
# [506 | 1750.56] loss=1.49 avg=2.05
# [507 | 1753.63] loss=1.54 avg=2.05
# [508 | 1756.70] loss=2.74 avg=2.05
# [509 | 1759.77] loss=1.17 avg=2.04
# [510 | 1762.84] loss=1.87 avg=2.04
# [511 | 1765.92] loss=1.72 avg=2.04
# [512 | 1768.97] loss=2.54 avg=2.04
# [513 | 1772.03] loss=2.54 avg=2.05
# [514 | 1775.11] loss=2.96 avg=2.06
# [515 | 1778.17] loss=2.45 avg=2.06
# [516 | 1781.24] loss=2.27 avg=2.06
# [517 | 1784.31] loss=2.37 avg=2.07
# [518 | 1787.38] loss=2.14 avg=2.07
# [519 | 1790.45] loss=1.84 avg=2.07
# [520 | 1793.52] loss=2.08 avg=2.07
# [521 | 1796.58] loss=1.11 avg=2.06
# [522 | 1799.65] loss=0.77 avg=2.04
# [523 | 1802.73] loss=1.62 avg=2.04
# [524 | 1805.81] loss=2.02 avg=2.04
# [525 | 1808.88] loss=1.03 avg=2.03
# [526 | 1811.96] loss=1.98 avg=2.03
# [527 | 1815.02] loss=2.27 avg=2.03
# [528 | 1818.10] loss=3.06 avg=2.04
# [529 | 1821.18] loss=2.49 avg=2.05
# [530 | 1824.26] loss=2.11 avg=2.05
# [531 | 1827.34] loss=1.47 avg=2.04
# [532 | 1830.43] loss=3.07 avg=2.05
# [533 | 1833.50] loss=1.72 avg=2.05
# [534 | 1836.58] loss=2.08 avg=2.05
# [535 | 1839.66] loss=1.55 avg=2.04
# [536 | 1842.73] loss=1.78 avg=2.04
# [537 | 1845.80] loss=2.35 avg=2.04
# [538 | 1848.86] loss=2.72 avg=2.05
# [539 | 1851.94] loss=2.68 avg=2.06
# [540 | 1855.02] loss=1.57 avg=2.05
# [541 | 1858.09] loss=1.85 avg=2.05
# [542 | 1861.17] loss=1.30 avg=2.04
# [543 | 1864.24] loss=1.33 avg=2.03
# [544 | 1867.32] loss=2.64 avg=2.04
# [545 | 1870.41] loss=1.03 avg=2.03
# [546 | 1873.47] loss=2.20 avg=2.03
# [547 | 1876.54] loss=1.56 avg=2.03
# [548 | 1879.61] loss=2.53 avg=2.03
# [549 | 1882.69] loss=2.25 avg=2.04
# [550 | 1885.77] loss=2.26 avg=2.04
# [551 | 1888.84] loss=1.08 avg=2.03
# [552 | 1891.91] loss=0.99 avg=2.02
# [553 | 1894.99] loss=0.81 avg=2.01
# [554 | 1898.06] loss=1.17 avg=2.00
# [555 | 1901.12] loss=2.14 avg=2.00
# [556 | 1904.19] loss=1.79 avg=2.00
# [557 | 1907.27] loss=2.67 avg=2.00
# [558 | 1910.35] loss=1.79 avg=2.00
# [559 | 1913.41] loss=3.13 avg=2.01
# [560 | 1916.48] loss=0.94 avg=2.00
# [561 | 1919.54] loss=1.06 avg=1.99
# [562 | 1922.60] loss=1.20 avg=1.98
# [563 | 1925.67] loss=0.98 avg=1.97
# [564 | 1928.74] loss=2.04 avg=1.97
# [565 | 1931.80] loss=1.79 avg=1.97
# [566 | 1934.87] loss=2.35 avg=1.98
# [567 | 1937.95] loss=1.03 avg=1.97
# [568 | 1941.02] loss=1.84 avg=1.97
# [569 | 1944.08] loss=2.47 avg=1.97
# [570 | 1947.14] loss=1.35 avg=1.96
# [571 | 1950.21] loss=2.33 avg=1.97
# [572 | 1953.28] loss=2.23 avg=1.97
# [573 | 1956.35] loss=2.44 avg=1.98
# [574 | 1959.42] loss=0.86 avg=1.96
# [575 | 1962.48] loss=1.81 avg=1.96
# [576 | 1965.55] loss=1.28 avg=1.96
# [577 | 1968.62] loss=1.83 avg=1.95
# [578 | 1971.68] loss=1.66 avg=1.95
# [579 | 1974.75] loss=2.31 avg=1.96
# [580 | 1977.81] loss=2.14 avg=1.96
# [581 | 1980.87] loss=1.21 avg=1.95
# [582 | 1983.94] loss=1.61 avg=1.95
# [583 | 1987.01] loss=1.02 avg=1.94
# [584 | 1990.09] loss=0.98 avg=1.93
# [585 | 1993.15] loss=1.89 avg=1.93
# [586 | 1996.21] loss=1.87 avg=1.93
# [587 | 1999.29] loss=2.64 avg=1.93
# [588 | 2002.35] loss=1.51 avg=1.93
# [589 | 2005.41] loss=0.86 avg=1.92
# [590 | 2008.48] loss=1.85 avg=1.92
# [591 | 2011.56] loss=2.89 avg=1.93
# [592 | 2014.64] loss=0.88 avg=1.92
# [593 | 2017.71] loss=1.13 avg=1.91
# [594 | 2020.78] loss=1.12 avg=1.90
# [595 | 2023.85] loss=1.17 avg=1.89
# [596 | 2026.91] loss=2.77 avg=1.90
# [597 | 2029.97] loss=1.05 avg=1.89
# [598 | 2033.04] loss=1.15 avg=1.89
# [599 | 2036.11] loss=1.43 avg=1.88
# [600 | 2039.19] loss=1.00 avg=1.87
# ======== SAMPLE 1 ========
#  but he said he could never have given us such false information. He said he had a very good conversation with me. What I said to him, & what he said, is a big lie! A total phony!
# Fake News is reporting that Democrats may be willing to negotiate the Dem loss of the House from Trump, even though the Dems had tremendous chances and wanted it. If this were to happen, the Fake News would be forced to report the truth!
# “The President has done more in the beginning. It’s been a rally, this Administration, it’s been a rally. I’m happy to have you back.”  @Ritz_B
# Thank you to @FoxNews for your great coverage. Enjoy!
# Great new book, “Cadillac Tax Gone Crazy” by Bruce Johnson, is just out. It is a celebration by far of the great American workers & their leaders who are fighting hard for lower taxes. Get it, it’s a must read. Buy the book - its for everyone!
# I will be interviewed live from the @WhiteHouse on @TuckerCarlson tonight at 7 PM. Enjoy!
# My warmest sympathies to the family and of a great leader, @EmmanuelMacron, President of France. You will be sorely missed. Praying for all well!
# We have an urgent investigation underway in France regarding the disgusting incident that took place in Charlie Hebdo. Our sympathies, and those of the United States as well, go out to President @Macron.
# “The President has never asked me not to investigate a White House incident involving a sitting president.”  Michael Cohen, pleading the Fifth!
# Leakin’ James Comey, as I have long suspected, is leaking Classified information to the press in an effort to embarrass and, more importantly, prove that the great men and women of the FBI, including brilliant FBI Academy Award winning Director Christopher Wray, were not acting appropriately. Can you believe this guy is FBI Director?
# Very funny that Republicans, who are running for office (and higher) because they are the Party of Trump, are happy to take money from lobbyists, the very groups that are heavily regulated, taxed & out of control. It is all the more reason why their candidate, the Democrats, will be outspent 5000 to 1!
# I am very proud of our great Farmers, Ranchers & all in the Food Chain!
# The President of France has just ruled out any further Terrorist activity against Europe, and the well being of the people of Europe. People can come to terms. Thanks France!
# I will be interviewed LIVE tonight by @JesseBWatters on @FoxNews  9:00 P.M. Enjoy!
# We have a very big & very beautiful ceremony today at the White House, but in an appropriate amount of time. The timing is perfect because of Thanksgiving. Merry Thanksgiving!
# Spoke with President Putin of Russia, which had nothing to do with our meeting. Much to discuss!
# Great job done by our GREAT Farmers, Ranchers & ALL in the Food Chain - great support from Russia and Turkey. We are in direct competition with one another, but that doesn’t matter, because the results are exactly the same. Best in business!
# We have taken $700 Billion dollars' worth of illegal actions against the H-2B Visa holders. The courts are giving us the right to legally bar people from our country. That would be so easy to do, and so harmless. But we must protect our workers, who are our main clients. So important!
# “It is ridiculous that they (the courts) haven’t found anything at this point. The Dems are saying they don’t have jurisdiction. Well, the courts are the law, but they can’t give any evidence of anything (allegations), they can’t bring anything (allegations). So far the courts have not been very helpful.” @MariaBartiromo
# It is the Democrats fault for being slow & obtuse on the Border & for wanting open Borders. They have missed their chance to set good relations with Russia. They have also given us no answers on Sanctuary Cities. Democrats, get back to work immediately and on Healthcare & Social Security!
# I will be interviewed by @MariaBartiromo at 9:00 PM on @FoxNews. Excellent job!
# If I didn’t love the people of Iran, and if the U.S. was happy, then I wouldn’t exist. But I do!
# ...
# I am en route to Camp David for official meetings on major Domestic Security topics.
# Got to know Rob Maness, who has been a great help to me on Criminal Justice and our Mass Incarceration Bill, very well. Rob is tough on Crime and has my full Endorsement!
# The Fake News Media is working overtime to blame me for the horrible shootings in Texas. They are just outrages. Always been safe, responsible, and very smart. Don’t they realize that most of the deaths are gang related?
# The NRA and the 2nd Amendment is the single greatest political force in the history of our Country! Defeat this historic threat now!
# I don’t know Putin, have no deals in Russia, and the haters & losers in the Democrat Party are losers, and they are working overtime to make us look as bad and bad as they possibly can. We are Winning big, and will continue to win, as the failing MSM tries to get going.
# The 2nd Amendment is a big and very popular right in this Country, but it is under siege. Every time we take another step back from something that should be so easy, it turns out to be an even bigger disaster. The people want safety, want security, and want FREEDOM!
# The NRA is out of business, gone, gone, never to be heard of again. Their website was taken, no longer exists. If it were up & running, which it is not, there would be no reason for them to exist. The Trump Administration is changing the LIES & SAYINGS on guns, much as I did. Big success, except in the Fake News!
# The 2nd Amendment is under siege. Get it done!
# Cambridge Analytica is a Cambridge Analytica, LLC registered in California. They make a POWERFUL series of statements, some very bad, about Muslims, that are very dangerous to many. They should be shut down and out of business.
# The Democrats in Congress must get rid of the loopholes on immigration. The flood gates and legal loopholes are killing our country. Must end birthright citizenship, big portions of which go to Democrats!
# The NRA is under siege. They make up a story that I don’t care about guns, which they are, because they don’t want them (even though they know this is true), and I don’t care about Muslims, who they are killing. Be safe, be smart!
# Will be going to Raleigh, North Carolina, tomorrow morning at 9:00 A.M. to meet with State and local leaders concerning our rapidly escalating crisis.
# .@DavidAsmanfox  “All four of the nine justices on the U.S. Supreme Court are Democrats. That’s the story you hear about them. But look at the facts. The news coverage has been more like sports coverage than about the economy. That’s why people tune in.”
# The Fake News Media has it purposely wrong. The Economy is doing GREAT. Most people do not understand, or do not want to understand, how vicious and destructive the Coronavirus is. It is a vicious and destructive disease. Democrats at State and Local levels are doing nothing but Obstructing, or refusing to listen to, the will of the people. Wake up America!
# We are going to Dallas, Texas. Big progress being made!
# I am in the White House 22 days a year. This will be a very successful year for us all. MAKE AMERICA GREAT AGAIN!
# Keep calm and move along, the world is watching!
# There was a great victory for peace and love last night. Thousands of rockets launched from Iran exploded in the air, damaging many cities. Also, contrary to the predictions of those same losers, Iran never fired a single weapon toward Israel. It is the U.S. that has willfully turned a blind eye to human rights violations and abuses against Iran!
# Will be going to New York next week to meet with A.G. Chuck Schumer and others. Will be discussing and helping to secure the long time future of N.Y.
# As everyone is aware, the past Administration has been very heavy handed with respect to Israel and the Middle East. But no more. The hard working men and women of the FBI & Department of Justice will do a GREAT job for the American people.
# The U.S. has lost 15,000 persons as a result of the CoronaVirus. We will be watching closely!
# Is this really acceptable? The U.S. Senate just approved a very big BIPARTISAN BOMB!
# Isn’t it a disgrace that the Israeli authorities are not doing nearly enough to stop the rocket fire from Iran - but when
#
# [2301 | 7937.64] loss=0.13 avg=0.14
# [2302 | 7940.71] loss=0.17 avg=0.14
# [2303 | 7943.77] loss=0.25 avg=0.14
# [2304 | 7946.83] loss=0.10 avg=0.14
# [2305 | 7949.90] loss=0.06 avg=0.14
# [2306 | 7952.96] loss=0.10 avg=0.14
# [2307 | 7956.01] loss=0.05 avg=0.13
# [2308 | 7959.09] loss=0.05 avg=0.13
# [2309 | 7962.15] loss=0.12 avg=0.13
# [2310 | 7965.23] loss=0.08 avg=0.13
# [2311 | 7968.29] loss=0.14 avg=0.13
# [2312 | 7971.36] loss=0.09 avg=0.13
# [2313 | 7974.44] loss=0.13 avg=0.13
# [2314 | 7977.51] loss=0.27 avg=0.13
# [2315 | 7980.58] loss=0.08 avg=0.13
# [2316 | 7983.66] loss=0.05 avg=0.13
# [2317 | 7986.74] loss=0.14 avg=0.13
# [2318 | 7989.80] loss=0.09 avg=0.13
# [2319 | 7992.87] loss=0.17 avg=0.13
# [2320 | 7995.97] loss=0.12 avg=0.13
# [2321 | 7999.04] loss=0.10 avg=0.13
# [2322 | 8002.11] loss=0.23 avg=0.13
# [2323 | 8005.19] loss=0.11 avg=0.13
# [2324 | 8008.26] loss=0.09 avg=0.13
# [2325 | 8011.33] loss=0.10 avg=0.13
# [2326 | 8014.40] loss=0.08 avg=0.13
# [2327 | 8017.49] loss=0.11 avg=0.13
# [2328 | 8020.56] loss=0.11 avg=0.13
# [2329 | 8023.64] loss=0.06 avg=0.13
# [2330 | 8026.71] loss=0.05 avg=0.13
# [2331 | 8029.79] loss=0.14 avg=0.13
# [2332 | 8032.86] loss=0.14 avg=0.13
# [2333 | 8035.93] loss=0.24 avg=0.13
# [2334 | 8039.00] loss=0.11 avg=0.13
# [2335 | 8042.05] loss=0.14 avg=0.13
# [2336 | 8045.14] loss=0.08 avg=0.13
# [2337 | 8048.21] loss=0.11 avg=0.13
# [2338 | 8051.27] loss=0.14 avg=0.13
# [2339 | 8054.35] loss=0.07 avg=0.13
# [2340 | 8057.42] loss=0.06 avg=0.13
# [2341 | 8060.50] loss=0.14 avg=0.13
# [2342 | 8063.57] loss=0.04 avg=0.13
# [2343 | 8066.65] loss=0.10 avg=0.13
# [2344 | 8069.73] loss=0.11 avg=0.13
# [2345 | 8072.81] loss=0.42 avg=0.13
# [2346 | 8075.88] loss=0.09 avg=0.13
# [2347 | 8078.95] loss=0.10 avg=0.13
# [2348 | 8082.03] loss=0.03 avg=0.13
# [2349 | 8085.11] loss=0.06 avg=0.13
# [2350 | 8088.19] loss=0.27 avg=0.13
# [2351 | 8091.26] loss=0.14 avg=0.13
# [2352 | 8094.33] loss=0.21 avg=0.13
# [2353 | 8097.40] loss=0.25 avg=0.13
# [2354 | 8100.48] loss=0.08 avg=0.13
# [2355 | 8103.55] loss=0.13 avg=0.13
# [2356 | 8106.62] loss=0.11 avg=0.13
# [2357 | 8109.70] loss=0.10 avg=0.13
# [2358 | 8112.76] loss=0.10 avg=0.13
# [2359 | 8115.85] loss=0.13 avg=0.13
# [2360 | 8118.92] loss=0.08 avg=0.13
# [2361 | 8122.00] loss=0.14 avg=0.13
# [2362 | 8125.08] loss=0.09 avg=0.13
# [2363 | 8128.16] loss=0.14 avg=0.13
# [2364 | 8131.23] loss=0.10 avg=0.13
# [2365 | 8134.31] loss=0.05 avg=0.13
# [2366 | 8137.40] loss=0.05 avg=0.13
# [2367 | 8140.47] loss=0.06 avg=0.13
# [2368 | 8143.56] loss=0.19 avg=0.13
# [2369 | 8146.64] loss=0.13 avg=0.13
# [2370 | 8149.71] loss=0.10 avg=0.13
# [2371 | 8152.80] loss=0.14 avg=0.13
# [2372 | 8155.87] loss=0.07 avg=0.13
# [2373 | 8158.95] loss=0.15 avg=0.13
# [2374 | 8162.02] loss=0.10 avg=0.13
# [2375 | 8165.10] loss=0.08 avg=0.13
# [2376 | 8168.19] loss=0.14 avg=0.13
# [2377 | 8171.26] loss=0.10 avg=0.13
# [2378 | 8174.33] loss=0.10 avg=0.13
# [2379 | 8177.40] loss=0.13 avg=0.13
# [2380 | 8180.47] loss=0.10 avg=0.13
# [2381 | 8183.54] loss=0.05 avg=0.13
# [2382 | 8186.62] loss=0.06 avg=0.12
# [2383 | 8189.71] loss=0.05 avg=0.12
# [2384 | 8192.79] loss=0.12 avg=0.12
# [2385 | 8195.85] loss=0.05 avg=0.12
# [2386 | 8198.93] loss=0.14 avg=0.12
# [2387 | 8202.02] loss=0.08 avg=0.12
# [2388 | 8205.10] loss=0.09 avg=0.12
# [2389 | 8208.17] loss=0.10 avg=0.12
# [2390 | 8211.26] loss=0.11 avg=0.12
# [2391 | 8214.33] loss=0.11 avg=0.12
# [2392 | 8217.42] loss=0.07 avg=0.12
# [2393 | 8220.49] loss=0.12 avg=0.12
# [2394 | 8223.57] loss=0.15 avg=0.12
# [2395 | 8226.65] loss=0.04 avg=0.12
# [2396 | 8229.74] loss=0.13 avg=0.12
# [2397 | 8232.81] loss=0.09 avg=0.12
# [2398 | 8235.88] loss=0.02 avg=0.12
# [2399 | 8238.96] loss=0.20 avg=0.12
# [2400 | 8242.03] loss=0.15 avg=0.12
# ======== SAMPLE 1 ========
#  WiCNN’S WORLD NOW!
# The Stock Market is up as much as 19% since the Election, and the unemployment numbers are the best in the history of the United States. We are also a net consumer of $496 Billion a year, which is more than France & The Netherlands combined. Big GDP gain!
# The unemployment numbers are fantastic, there are many reasons for this, including the Nov. 7 Election victory. But the real story is the Economy, which is doing well, and will only get better!
# Our legal system is broken down and inefficient, especially when it comes to getting high level officials to testify. There is tremendous corruption against the United States on grandstanding President Impeachment. We will get it fixed one way or the other!
# PRESIDENTIAL HARASSMENT!
# The Fake News gets crazier and more dishonest every single day. This Impeachment Scam is just the tip of the iceberg. There is much more to come!
# Remember when the Judges at the Southern District of New York were working overtime putting out false information? This Impeachment Scam is just the tip of the iceberg. There are so many crimes that can and will be committed by the Democrats, but working hard to tarnish & demean!
# Where is the apology to President I of Iran for trying to kill the elected President of that same country, and butchering millions of innocent Iranians with a mysterious virus. How is TSA doing?
# Terrific new book out by the wonderful Harris Faulkner, “10,000 Days To Mars.” Harris will make a tremendous Admiral. He is a great guy who loves our Military and our Vets. Check it out today, they are great!
# Senator Dicky Durbin just wrote a wonderful book, “Our Shining Moment: A Day In the Life Of John James—The Early Years” We are all in a blessed moment to be an American people. The Left has lost touch!
# Iran has long been warning that it will be taken down one way or the other, and have not done anything to slow down or stop the massive IRNA Group. They have enriched to such an extent that it would be hard to get back into business. They have taken advantage of the U.S. for many years. Sanctions will soon be broken, or not reported at all!
# Representative Adam Schiff has been calling in sick for three days, and doing the same thing over and over again, which he knows is not true, even though he has a perfect legal case. He is a sick man!
# MAKE AMERICA GREAT AGAIN!
# Iran has long been warning that it will be taken down one way or the other, and have not done anything to slow it down. They have enriched to such an extent that it would be hard to get back into business. They have never been more deceptive than they are right now!
# The Stock Market is headed up, as usual, unfairly by outside groups. However, the Fake News Media does everything possible to under the guise of journalism to take the heat, and in some cases, the “pressure” of the Fake Election. It is all unfair and just plain incorrect!
# Everywhere I look at the Obama Administration, even though it may be a long time in coming, they have left more than they found. They have done little since coming into office, and do very little now. The swamp is getting deeper and deeper. President Obama was a total loser!
# “The Dems are getting fewer and farther away from the people in the Trump Administration. The press is equally bad!” Jason Chaffetz
# I am getting great reviews for my State of the Union Speech than the Democrats, who have done nothing but say what they want to do and say, have gotten away with. Fake News Media, they are truly the Enemy of the People!
# The White House is running very smoothly, with few exceptions. There has even been some splintering at the Border. Even Chuck Schumer got confused! We have done a lot of work, and will do much more!
# The Democrats will do anything to avoid a Republican House or Senate win in 2018. The Border is our Country, and our Walls are our Defense!
# I will be live from the White House at 4:00 P.M.
# Mexico is paying for the Wall through the new USMCA, the replacement for NAFTA! This is strictly on top of the $39.6 billion already approved for the Wall. No new money.
# The Democrats are the problem. They don’t care about Crime in their country, they don’t want Billions of Dollars, they are just looking for a fight. Mexico is paying, and will pay, for the Wall through the soon to be completed fiscal year (Jan. 2019).
# Hard to believe that someone can write a book claiming to be my oldest daughter’s lover, called Betty, and make it so I did not know she was the
#
# [2401 | 8281.81] loss=0.15 avg=0.12
# [2402 | 8284.87] loss=0.12 avg=0.12
# [2403 | 8287.92] loss=0.09 avg=0.12
# [2404 | 8290.97] loss=0.13 avg=0.12
# [2405 | 8294.02] loss=0.09 avg=0.12
# [2406 | 8297.08] loss=0.07 avg=0.12
# [2407 | 8300.14] loss=0.22 avg=0.12
# [2408 | 8303.19] loss=0.05 avg=0.12
# [2409 | 8306.26] loss=0.10 avg=0.12
# [2410 | 8309.33] loss=0.04 avg=0.12
# [2411 | 8312.38] loss=0.17 avg=0.12
# [2412 | 8315.44] loss=0.09 avg=0.12
# [2413 | 8318.51] loss=0.06 avg=0.12
# [2414 | 8321.58] loss=0.12 avg=0.12
# [2415 | 8324.64] loss=0.06 avg=0.12
# [2416 | 8327.72] loss=0.06 avg=0.12
# [2417 | 8330.79] loss=0.12 avg=0.12
# [2418 | 8333.86] loss=0.05 avg=0.12
# [2419 | 8336.93] loss=0.20 avg=0.12
# [2420 | 8340.00] loss=0.06 avg=0.12
# [2421 | 8343.07] loss=0.14 avg=0.12
# [2422 | 8346.14] loss=0.02 avg=0.12
# [2423 | 8349.20] loss=0.14 avg=0.12
# [2424 | 8352.28] loss=0.06 avg=0.12
# [2425 | 8355.35] loss=0.15 avg=0.12
# [2426 | 8358.42] loss=0.16 avg=0.12
# [2427 | 8361.50] loss=0.09 avg=0.12
# [2428 | 8364.57] loss=0.16 avg=0.12
# [2429 | 8367.64] loss=0.07 avg=0.12
# [2430 | 8370.71] loss=0.18 avg=0.12
# [2431 | 8373.78] loss=0.06 avg=0.12
# [2432 | 8376.85] loss=0.13 avg=0.12
# [2433 | 8379.93] loss=0.13 avg=0.12
# [2434 | 8382.99] loss=0.06 avg=0.12
# [2435 | 8386.07] loss=0.05 avg=0.12
# [2436 | 8389.14] loss=0.06 avg=0.12
# [2437 | 8392.20] loss=0.12 avg=0.12
# [2438 | 8395.26] loss=0.07 avg=0.12
# [2439 | 8398.33] loss=0.08 avg=0.11
# [2440 | 8401.39] loss=0.06 avg=0.11
# [2441 | 8404.46] loss=0.09 avg=0.11
# [2442 | 8407.51] loss=0.05 avg=0.11
# [2443 | 8410.56] loss=0.12 avg=0.11
# [2444 | 8413.62] loss=0.16 avg=0.11
# [2445 | 8416.68] loss=0.12 avg=0.11
# [2446 | 8419.75] loss=0.12 avg=0.11
# [2447 | 8422.81] loss=0.08 avg=0.11
# [2448 | 8425.87] loss=0.24 avg=0.12
# [2449 | 8428.94] loss=0.15 avg=0.12
# [2450 | 8432.00] loss=0.28 avg=0.12
# [2451 | 8435.05] loss=0.11 avg=0.12
# [2452 | 8438.11] loss=0.11 avg=0.12
# [2453 | 8441.17] loss=0.12 avg=0.12
# [2454 | 8444.24] loss=0.06 avg=0.12
# [2455 | 8447.30] loss=0.05 avg=0.12
# [2456 | 8450.37] loss=0.14 avg=0.12
# [2457 | 8453.43] loss=0.04 avg=0.12
# [2458 | 8456.50] loss=0.18 avg=0.12
# [2459 | 8459.56] loss=0.06 avg=0.12
# [2460 | 8462.63] loss=0.06 avg=0.11
# [2461 | 8465.69] loss=0.10 avg=0.11
# [2462 | 8468.74] loss=0.10 avg=0.11
# [2463 | 8471.80] loss=0.11 avg=0.11
# [2464 | 8474.85] loss=0.16 avg=0.11
# [2465 | 8477.91] loss=0.17 avg=0.12
# [2466 | 8480.96] loss=0.13 avg=0.12
# [2467 | 8484.01] loss=0.15 avg=0.12
# [2468 | 8487.05] loss=0.07 avg=0.12
# [2469 | 8490.09] loss=0.06 avg=0.11
# [2470 | 8493.16] loss=0.13 avg=0.12
# [2471 | 8496.22] loss=0.11 avg=0.11
# [2472 | 8499.28] loss=0.14 avg=0.12
# [2473 | 8502.34] loss=0.06 avg=0.11
# [2474 | 8505.40] loss=0.06 avg=0.11
# [2475 | 8508.46] loss=0.09 avg=0.11
# [2476 | 8511.53] loss=0.15 avg=0.11
# [2477 | 8514.58] loss=0.15 avg=0.11
# [2478 | 8517.62] loss=0.03 avg=0.11
# [2479 | 8520.68] loss=0.12 avg=0.11
# [2480 | 8523.73] loss=0.09 avg=0.11
# [2481 | 8526.81] loss=0.19 avg=0.11
# [2482 | 8529.87] loss=0.06 avg=0.11
# [2483 | 8532.94] loss=0.16 avg=0.11
# [2484 | 8536.01] loss=0.08 avg=0.11
# [2485 | 8539.07] loss=0.14 avg=0.11
# [2486 | 8542.12] loss=0.08 avg=0.11
# [2487 | 8545.17] loss=0.09 avg=0.11
# [2488 | 8548.22] loss=0.07 avg=0.11
# [2489 | 8551.27] loss=0.10 avg=0.11
# [2490 | 8554.32] loss=0.07 avg=0.11
# [2491 | 8557.37] loss=0.11 avg=0.11
# [2492 | 8560.41] loss=0.14 avg=0.11
# [2493 | 8563.45] loss=0.08 avg=0.11
# [2494 | 8566.49] loss=0.11 avg=0.11
# [2495 | 8569.54] loss=0.08 avg=0.11
# [2496 | 8572.58] loss=0.12 avg=0.11
# [2497 | 8575.62] loss=0.07 avg=0.11
# [2498 | 8578.67] loss=0.09 avg=0.11
# [2499 | 8581.71] loss=0.45 avg=0.11
# [2500 | 8584.76] loss=0.11 avg=0.11
# Saving checkpoint/run2500-newer/model-2500

# %% [markdown]
# If you're creating an API based on your model and need to pass the generated text elsewhere, you can do `text = gpt2.generate(sess, return_as_list=True)[0]`
#
# You can also pass in a `prefix` to the generate function to force the text to start with a given character sequence and generate text from there (good if you add an indicator when the text starts).
#
# You can also generate multiple texts at a time by specifing `nsamples`. Unique to GPT-2, you can pass a `batch_size` to generate multiple samples in parallel, giving a massive speedup (in Colaboratory, set a maximum of 20 for `batch_size`).
#
# Other optional-but-helpful parameters for `gpt2.generate` and friends:
#
# *  **`length`**: Number of tokens to generate (default 1023, the maximum)
# * **`temperature`**: The higher the temperature, the crazier the text (default 0.7, recommended to keep between 0.7 and 1.0)
# * **`top_k`**: Limits the generated guesses to the top *k* guesses (default 0 which disables the behavior; if the generated output is super crazy, you may want to set `top_k=40`)
# * **`top_p`**: Nucleus sampling: limits the generated guesses to a cumulative probability. (gets good results on a dataset with `top_p=0.9`)
# * **`truncate`**: Truncates the input text until a given sequence, excluding that sequence (e.g. if `truncate='<|endoftext|>'`, the returned text will include everything before the first `<|endoftext|>`). It may be useful to combine this with a smaller `length` if the input texts are short.
# *  **`include_prefix`**: If using `truncate` and `include_prefix=False`, the specified `prefix` will not be included in the returned text.

# %%
gpt2.generate(sess, run_name=run_Name)
# Out:
# Stephen Miller, the wonderful CEO of the New York Times, is upset that his paper did not report that the Fake News New York Times changed the heading of its badly reported story on me, just like so many others, in order to make it look as bad as possible. He is a truly bad guy!
# The Arena was packed to the rafters with the crowd, who were so happy to see their team, were unable to leave the building. This was a total flop, and the paper will pay a big price for their poor reporting!
# I am pleased to announce that our very talented Deputy Secretary of Defense, Patrick Shanahan, will assume the title of Acting Secretary of Defense starting January 1, 2019. I am looking forward to being with Patrick, and looking forward to being with our great men and women of the F.B.
# When President Obama called me to congratulate me on reaching 270,000 signatures on a petition to change the title of the President, I said “Thank you Mr. President. I appreciate your call. I will get back to you soon. 270,000 is a lot of support, and I’m signing it because it’s the right thing to do.” You would have no support from me!
# I will be interviewed by @MariaBartiromo on @FoxNews at 10:00 AM. Russian Collusion Hoax!
# I will be interviewed by @JesseBWatters on @FoxNews at 10:00 AM. Illegal Russian Collusion?
# I will be interviewed by @BretBaier on @FoxNews at 10:00 AM. Trump, Comey, McCabe, Strzok and Munson are all illegal scammers and partisans. The only thing we have to fear is Fake News CNN and NBC, and their combination. Enjoy!
# Julian Assange, the beloved head of the CIA, has just been walking around the Ecuadorian Embassy in Knightsbridge, London, bragging and boasting about how he got the POWs from Iran, and gave them to Wikileaks. Some of the BEST FREE NEWS ever!
# The Fake News Media has never been more corrupt or desperate than it is right now. There is no longer a war on the Fake News Media. It is a fake media, as usual. Every story or report, even if should have been proven LIKELY in the past, is now just a made up story with sources and leakers that don’t even exist. It is FAKE NEWS!
# The Stop Online Piracy Act (S.1562) is about as bad for your online privacy as the USA will ever come!
# The Fake News Media is going wild trying to predict what groups of people will be most upset by the fact that I’m President. Some groups are more upset than others. We will see!
# We have just reached a very sad milestone with the coronavirus pandemic deaths reaching 100,000. To all of the families & friends of those who have passed, I want to extend my heartfelt sympathy & love for everything that these great people stood for & represent. God be with you!
# I will be interviewed by @seanhannity on @FoxNews at 10:00 AM. Enjoy!
# We have just reached a very sad milestone with the coronavirus pandemic deaths reaching 100,000. To all of the families & friends of those who have lost their loved ones in this great act of kindness, I want to extend my heartfelt sympathy & love for everything that these great people stood for & represent. God be with you!
# I will be interviewed by @seanhannity on @FoxNews at 10:00 AM. Enjoy!
# We have just reached a very sad milestone with the coronavirus pandemic deaths reaching 100,000. To all of the families & friends of those who have lost their loved ones in this great act of kindness, I want to extend my heartfelt sympathy & love for everything that these great people stood for & represent. God be with you!
# Will be interviewed by @seanhannity tonight at 9:00 AM on @FoxNews. Enjoy!
# The United States has just reached an absolutely historic agreement with China concerning the release and re-entry of highly contagious, highly dangerous and very expensively produced contraband. Thank you to all!
# The unthinkable has happened - Blue Lives Matter. The MSM doesn’t want to report it, or acknowledge it, because it could get me elected (of course!). But it could also get you (of course)!
# The White House is running very smoothly despite phony Witch Hunts and a Fake News Media. Because I have done nothing wrong!
# Democrats don’t want to approve $2.96 billion for the Southern Border. They are fighting tooth and nail to not even give it a yes. If Nancy Pelosi gave it a yes, we would see some heart!
# The Fake News Media is going wild trying to believe that any of the three psychologists (not two

# %%
import random
tf.reset_default_graph()
sess = gpt2.start_tf_sess()
gpt2.copy_checkpoint_from_gdrive(run_name=run_Name)
gpt2.load_gpt2(sess, run_name=run_Name)
single_text = gpt2.generate(sess, run_name=run_Name, return_as_list=True)[0]
one_line = single_text.split("\n")[random.randint(0,len(arr)-1)]
print(single_text)
# Out:
# Loading checkpoint checkpoint/run2500-newer/model-2500
# INFO:tensorflow:Restoring parameters from checkpoint/run2500-newer/model-2500
# Democrats are so self righteous. If not for the great jobs numbers, we would be down to a very small number of people, and our Country would be devastated. But we get great numbers, and that’s all that matters!

# %% [markdown]
# For bulk generation, you can generate a large amount of text to a file and sort out the samples locally on your computer. The next cell will generate a generated text file with a unique timestamp.
#
# You can rerun the cells as many times as you want for even more generated texts!

# %%
# gen_file = 'gpt2_gentext_{:%Y%m%d_%H%M%S}.txt'.format(datetime.utcnow())

# gpt2.generate_to_file(sess,
#                       destination_path=gen_file,
#                       length=500,
#                       temperature=0.7,
#                       nsamples=100,
#                       batch_size=20
#                       )

# %%
# # may have to run twice to get file to download
# files.download(gen_file)
# Out:
# Loading checkpoint checkpoint/run2500-newer/model-2500
# INFO:tensorflow:Restoring parameters from checkpoint/run2500-newer/model-2500
# The New York Times is an embarrassment to journalism. They were a dead paper before I went into politics, and they will be a dead paper after I leave, which will be in 5 years. Fake News is the Enemy of the people!
